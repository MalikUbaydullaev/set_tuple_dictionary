# %% [markdown]
# ## Lists

# %%
type([])
# Out:
# list

# %%
lst_example = []
type(lst_example)
# Out:
# list

# %%
lst = list()
lst = ['Math', 'Chemistry', 'Informatics']
print(lst)
# Out:
# ['Math', 'Chemistry', 'Informatics']

# %%
len(lst)
# Out:
# 3

# %% [markdown]
# ### Append

# %%
lst.append("Biology")
lst
# Out:
# ['Math', 'Chemistry', 'Informatics', 'Biology']

# %%
lst[0]
# Out:
# 'Math'

# %%
lst[1:]
# Out:
# ['Chemistry', 'Informatics', 'Biology']

# %%
print(lst[0:5])
print(lst[:4])
# Out:
# ['Math', 'Chemistry', 'Informatics', 'Biology']
# ['Math', 'Chemistry', 'Informatics', 'Biology']

# %%
lst.append(["Physics", "English"])

# %%
lst
# Out:
# ['Math', 'Chemistry', 'Informatics', 'Biology', ['Physics', 'English']]

# %% [markdown]
# ### Insert

# %%
# Insert in a specific order
lst.insert(1, "Medicine")

# %%
lst
# Out:
# ['Math',
#  'Medicine',
#  'Chemistry',
#  'Informatics',
#  'Biology',
#  ['Physics', 'English']]

# %% [markdown]
# ## Extend Method

# %%
lst2 = [1, 2, 3, 4, 5, 6]

# %%
lst2.extend([8, 9])
lst2
# Out:
# [1, 2, 3, 4, 5, 6, 8, 9]

# %% [markdown]
# ### Various Operations that we can perform in List

# %%
lst3 = [1, 2, 3, 4, 5, 6]

# %%
sum(lst3)
# Out:
# 21

# %% [markdown]
# ### Pop Method

# %%
lst2.pop()
# Out:
# 9

# %%
lst2
# Out:
# [1, 2, 3, 4, 5, 6, 8]

# %% [markdown]
# ### Count

# %%
lst2
# Out:
# [1, 2, 3, 4, 5, 6, 8]

# %%
lst2.append(5)
lst2
# Out:
# [1, 2, 3, 4, 5, 6, 8, 5]

# %%
lst2.count(5)
# Out:
# 2

# %%
lst2.index(3)
# Out:
# 2

# %%
min(lst2)
# Out:
# 1

# %%
max(lst2)
# Out:
# 8

# %%
lst2 * 2
# Out:
# [1, 2, 3, 4, 5, 6, 8, 5, 1, 2, 3, 4, 5, 6, 8, 5]

# %%
lst2 * 3
# Out:
# [1, 2, 3, 4, 5, 6, 8, 5, 1, 2, 3, 4, 5, 6, 8, 5, 1, 2, 3, 4, 5, 6, 8, 5]

# %% [markdown]
# ### Sets

# %%
## Defining an empty set

set_var = set()
print(set_var)
print(type(set_var))
# Out:
# set()
# <class 'set'>

# %%
set_var = {"Avengers", "IronMan", "Hitman"}
set_var1 = {"Avengers", "IronMan", "Hitman", "Spiderman"}

# %%
print(set_var)
# Out:
# {'IronMan', 'Hitman', 'Avengers'}

# %%
set_var2 = {1, 2, 3, 4, 1}

# %%
set_var2
# Out:
# {1, 2, 3, 4}

# %%
set_var.add('Hulk')
set_var
# Out:
# {'Avengers', 'Hitman', 'Hulk', 'IronMan'}

# %%
# indexing ton't working here
set_var1.difference(set_var)
set_var1
# Out:
# {'Avengers', 'Hitman', 'IronMan', 'Spiderman'}

# %%
set_var1.intersection(set_var)
# Out:
# {'Avengers', 'Hitman', 'IronMan'}

# %% [markdown]
# ## Dictionaries

# %%
dic = {}

# %%
type(dic)
# Out:
# dict

# %%
## Create dictionary
my_dict = {"Car1" : "Audi", "Car2" : "BMW", "Car3" : "Porshe"}
my_dict
# Out:
# {'Car1': 'Audi', 'Car2': 'BMW', 'Car3': 'Porshe'}

# %%
type(my_dict)
# Out:
# dict

# %%
my_dict['Car1']
# Out:
# 'Audi'

# %%
for x in my_dict:
    print(x)
# Out:
# Car1
# Car2
# Car3

# %%
for x in my_dict.values():
    print(x)
# Out:
# Audi
# BMW
# Porshe

# %%
for x in my_dict.items():
    print(x)
# Out:
# ('Car1', 'Audi')
# ('Car2', 'BMW')
# ('Car3', 'Porshe')

# %%
my_dict['Car4'] = 'Mercedes Benz'

# %%
my_dict
# Out:
# {'Car1': 'Audi', 'Car2': 'BMW', 'Car3': 'Porshe', 'Car4': 'Mercedes Benz'}

# %% [markdown]
# ### Nested Dictionary

# %%
car1_model = {'Mercedes' : 1960}
car2_model = {'Audi' : 1970}
car3_model = {'BMW' : 1990}

# %%
car_models = {'car1' : car1_model, 'car2' : car2_model, 'car3' : car3_model}

# %%
print(car_models)
# Out:
# {'car1': {'Mercedes': 1960}, 'car2': {'Audi': 1970}, 'car3': {'BMW': 1990}}

# %%
print(car_models['car2']['Audi'])
# Out:
# 1970

# %% [markdown]
# ### Tuples

# %%
my_tuple = tuple()

# %%
my_tuple = ("Bir", "Ikki" , "Uch")

# %%
my_tuple[0]
# Out:
# 'Bir'

# %%
print(type(my_tuple))
# Out:
# <class 'tuple'>

# %%
print(my_tuple)
# Out:
# ('Bir', 'Ikki', 'Uch')

# %%
my_tuple.count('Bir')
# Out:
# 1

# %%
my_tuple.index('Ikki')
# Out:
# 1
